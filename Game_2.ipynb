# %%
import random

import sys

from random import choices


def credentials():
    # here i tell ask him for a user name to a better experience

    user_name = input("Prompt="
        'Welcome to Super League Tournament,This is the tournament with the most history currently being played in soccer,\n'
        'played since 1960. \n'
        'The team that has won it the most times is Real Madrid with nine titles, this tournament is for the champions\n'
        ' of the local leagues in ecah country of Europe.'
        'The champion of the Super League Tournament, will face with the \n'
        'champion of the Super League Tournament of America to choose the best team of the \n'
        'Year. "Write User Name"'
        )

    # the game ask for a password to have a better security in you profile create

    password = input("Prompt=""write password")

    # in this step i will choose a player, there are 3 options, the game give you the option to add one of this 3 players to your team

    player_seleccion = input("prompt="
        ' Cristiano Ronaldo dos Santos Aveiro born 5 February 1985 is a Portuguese professional footballer \n'
        'who plays as a forward for Premier League club Manchester United and captains the Portugal \n'
        'national team. Often considered the best player in the world and widely regarded as one of the \n'
        'greatest players of all time, Ronaldo has won five Ballon de Oro awards and four European Golden \n'
        'Shoes, the most by a European player. He has won 32 trophies in his career, including seven \n'
        'league titles, five UEFA Champions Leagues, one UEFA European Championship and one UEFA \n'
        'Nations League. Ronaldo holds the records for most appearances 179, most goals 137 and assists \n'
        '42 in the Champions League, most goals in the European Championship 14, most international \n'
        'goals by a male player 115, and most international appearance by a European male 182. He is one\n'
        'of the few players to have made over 1,100 professional career appearances and has scored over 790 \n'
        'official senior career goals for club and country.\n'
        'Lionel Andrés Messi  born 24 June 1987, also known as Leo Messi, is an Argentine professional \n'
        'footballer who plays as a forward for Ligue 1 club Paris Saint-Germain and captains the Argentina\n'
        'national team. Often considered the best player in the world and widely regarded as one of the \n'
        'greatest players of all time, Messi has won a record six Ballon de Oro awards, a record six \n'
        'European Golden Shoes, and in 2020 was named to the Ballon de Oro Dream Team. Until leaving \n'
        'the club in 2021, he had spent his entire professional career with Barcelona, where he won a club\n'
        'record 35 trophies, including ten La Liga titles, seven Copa del Rey titles and four UEFA Champions \n'
        'Leagues. A prolific goalscorer and creative playmaker, Messi holds the records for most goals in La \n'
        'Liga 474, a La Liga and European league season 50, most hat-tricks in La Liga 36 and the UEFA \n'
        'Champions League 8, and most assists in La Liga 192, a La Liga season 21 and the Copa América 17. \n'
        ' Messi has scored over 750 senior career goals for \n'
        'club and country and has the most goals by a player for a single club.\n'
        'Neymar da Silva Santos Júnior born 5 February 1992, known as Neymar, is a Brazilian professional \n'
        'footballer who plays as a forward for Ligue 1 club Paris Saint-Germain and the Brazil national \n'
        'team. He is widely regarded as one of the best players of his generation. Neymar came into \n'
        'prominence at Santos, where he made his professional debut aged 17. He helped the club win two \n'
        'successive Campeonato Paulista championships, a Copa do Brasil, and the 2011 Copa \n'
        'Libertadores, the latter being Santos first since 1963. Neymar was twice named the South American Footballer \n'
        'of the Year, in 2011 and 2012, and soon relocated to Europe to join Barcelona. As part of \n'
        'Barcelona attacking trio with Lionel Messi and Luis Suárez, he won the continental treble of La \n'
        'Liga, the Copa del Rey, and the UEFA Champions League, and finished third for the FIFA Ballon de \n'
        'Oro in 2015 for his performances. He then attained a domestic double in the 2015–16 season. In \n'
        '2017, Neymar transferred to Paris Saint-Germain in a move worth €222 million, making him the \n'
        'most expensive player ever. In France, Neymar won three league titles, three Coupe de France, \n'
        'and two Coupe de la Ligue, which included a domestic treble and being voted Ligue 1 Player of the \n'
        'Year in his debut season. Neymar helped PSG attain a domestic quadruple in the 2019 –20 season \n'
        'and led the club to its first ever Champions League Final.\n'
        ''
        ' '
        ''
        ' : [Cristiano Ronaldo/Lionel Messi/Neymar]"')

    if player_seleccion.lower() == "Cristiano Ronaldo":
        print("Prompt=""you decide Cristiano Ronaldo")

    elif player_seleccion.lower() == "Lionel Messi":
        print("Prompt=""you decide Lionel Messi")

    elif player_seleccion.lower() == "Neymar":
        print("Prompt=""you decide to be Neymar")

    return player_seleccion


def Stage_1(ii):
    print("Prompt=""hello",
          ii)  # ii is  the variable that you are using to "remember" the name of your player from the function--- credentials---
    # remember that when  you call this function you need to assign it a variable
    # in this step you choose a team to play the Super League Tournament.
    team_Seleccion = input("Prompt=""please select a team : [Psg,Real Madrid,Milan]\n"
                           ""

                           "Paris Saint-Germain Football Club, commonly referred to as Paris Saint-Germain, PSG, Paris or\n"
                           "Paris SG, is a professional football club based in Paris, France. They compete in Ligue 1, the top \n"
                           "division of French football. France most successful club, they have won over 40 official honours, \n"
                           "including nine league titles and one major European trophy. Their home ground is the Parc des \n"
                           "Princes. Founded in 1970, the Parisians won their first major honour, the French Cup, in 1982 and \n"
                           "their first Ligue 1 title in 1986. The 1990s was among the most successful periods in PSG history; \n"
                           "they claimed a second league, three French Cups, two French League Cups, two French Super Cups \n"
                           "and the UEFA Cup Winners Cup in 1996. After suffering a decline in fortunes during the 2000s, the \n"
                           "Red and Blues have enjoyed a revival since 2011 with increased financial backing, achieving \n"
                           "unparalleled dominance in domestic competitions, winning seven league titles and twenty\n"
                           "national cups. PSG have also become a regular feature in the UEFA Champions League, reaching their first final in 2020.\n"
                           "Real Madrid Club de Fútbol Spanish pronunciation: meaning Royal Madrid Football Club commonly \n"
                           "referred to as Real Madrid, is a Spanish professional football club based in Madrid. Founded on 6 \n"
                           "March 1902 as Madrid Football Club, the club has traditionally worn a white home kit since \n"
                           "inception. The honorific title real is Spanish for royal and was bestowed to the club by King Alfonso \n"
                           "XIII in 1920 together with the royal crown in the emblem. The team has played its home matches \n"
                           "in the 81,044-capacity Santiago Bernabéu Stadium in downtown Madrid since 1947. Unlike most \n"
                           "European sporting entities, Real Madrid's members socios have owned and operated the club \n"
                           "throughout its history. The club was estimated to be worth €3.8 billion $4.2 billion in 2019, and it \n"
                           "was the second highest-earning football club in the world, with an annual revenue of €757.3 \n"
                           "million in 2019. The club is one of the most widely supported teams in the world.  Real Madrid is \n"
                           "one of three founding members of La Liga that have never been relegated from the top division \n"
                           "since its inception in 1929, along with Athletic Bilbao and Barcelona. The club holds many long-\n"
                           "standing rivalries, most notably El Clásico with Barcelona and El Derbi Madrileño with Atlético Madrid.")

    if team_Seleccion.lower() == "Psg":
        print("Prompt=""you decided Psg")

    if team_Seleccion.lower() == "Real Madrid":
        print("Prompt=""you decided Real Madrid")

    if team_Seleccion.lower() == "Milan":
        print("Prompt=""you decided Milan")

    return team_Seleccion

# using the random function the game choose an opponent
# these is the list of the opponents of the team the user choose.
def stage_2():
    all_teams = ["Real Sociedad", "Sevilla", "Valencia", "Liverpool", "Everton", "Manchester United", "Milan",
                 "Fiorentina", "Atalanta", "New castle"]
    opponent = str(choices(all_teams))

    print("Prompt=""your team is going to play with:", opponent)


# In this point randomly the game give me scrores and if i get more gols than my opponnent i get 3 points, if the two teams
# became iqual, i have one point and if i lose i get cero points.

def simulate_game():
    team_1 = random.randint(0, 5)
    team_2 = random.randint(0, 5)

    print(team_1, team_2)
    if team_1 > team_2:
        print("Prompt=""your team wins")
    elif team_2 > team_1:
        print("Prompt=""the opponents win")
    else:
        print("Prompt=""its a draw")

# In this step the schedule of matches to be played is defined randomly
#will be assigned a random marker between 0 and 5


def calendar(my_team):
    calendar_list = ["Real Sociedad", "Sevilla", "Valencia", "Liverpool"]

    score_team = []

    score_opponent = []

    for i in calendar_list:
        first_random = random.randint(0, 5)
        second_random = random.randint(0, 5)

        print(my_team, "vs", i, "score:  ----------------", first_random, "-", second_random)

        if first_random > second_random:
            score_team.append(3), score_opponent.append(0)
        elif first_random < second_random:
            score_team.append(0), score_opponent.append(3)
        elif first_random == second_random:
            score_team.append(1), score_opponent.append(1)

        print((sum(score_team), "-------", sum(score_opponent)))

    total_score = (sum(score_team))
# At this point, the sum of the points obtained in the games played is
# made and if it is greater than 8 points, it goes to the next round, if
#it is less than 8 points, the team is eliminated.

    print("Prompt=""your team total score is: ", total_score)
    if total_score >= 8:

        print("Prompt=""you pass to the next round")
        Round_2()
    else:

        print("Prompt=""you are eliminate")


# the opponent of the next round is defined, if he wins the match he
#goes to the next phase, if he loses he is eliminated.


#calendar(Stage_1(credentials()))

#These are the possible opponents if the team goes to the second phase
# If the team wins, it will go to the next phase of the game.
#on the contrary, if it loses, it will be eliminated.
#If it surpasses the teams of the second phase, it will be the champion.


def Round_2():
        counter = 0

        Teams_Round_2 = list(["Manchester City", "Juventus", "Fiorentina"])

        print(Teams_Round_2)

        for i in range(len(Teams_Round_2)):

            Random_Team = (",".join(random.choices(Teams_Round_2)))

            print("Prompt="f"your playing against {Random_Team}")

            team_1 = random.randint(0, 5)
            team_2 = random.randint(0, 5)

            print(team_1, team_2)
            if team_1 > team_2:

                print("Prompt=""your team goes to the next phase")
                counter += 1

                if counter == 3:
                    print("Prompt=""you won the championship!!")





            elif team_2 > team_1:
                print("Prompt=""your team is eliminated")
                sys.exit(0)

            elif counter == 2:
                print("Prompt=""you won the championship!!")


            else:
                print("Prompt=""its a draw")
                sys.exit(0)

            index = Teams_Round_2.index(Random_Team)
            Teams_Round_2.pop(index)



calendar(Stage_1(credentials()))

stage_2()

simulate_game()




Round_2()
# Out:
# Prompt=Welcome to Super League Tournament,This is the tournament with the most history currently being played in soccer,
# played since 1960.
# The team that has won it the most times is Real Madrid with nine titles, this tournament is for the champions
#  of the local leagues in ecah country of Europe.The champion of the Super League Tournament, will face with the
# champion of the Super League Tournament of America to choose the best team of the
# Year. "Write User Name"a
# Prompt=write passworda
# prompt= Cristiano Ronaldo dos Santos Aveiro born 5 February 1985 is a Portuguese professional footballer
# who plays as a forward for Premier League club Manchester United and captains the Portugal
# national team. Often considered the best player in the world and widely regarded as one of the
# greatest players of all time, Ronaldo has won five Ballon de Oro awards and four European Golden
# Shoes, the most by a European player. He has won 32 trophies in his career, including seven
# ...
